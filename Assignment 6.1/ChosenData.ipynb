# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('energydata_complete.csv')

print('Number of Columns', len(df.columns))
print('Number of Rows', len(df))
# Out:
# Number of Columns 29
# Number of Rows 19735

# %%
print('Data Types/Formats', df.dtypes)
# Out:
# Data Types/Formats date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %%
df.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
df.tail(10)
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19725  2016-05-27 16:30:00         220       0  25.426667  46.060000
# 19726  2016-05-27 16:40:00         180       0  25.500000  46.530000
# 19727  2016-05-27 16:50:00         120       0  25.500000  47.456667
# 19728  2016-05-27 17:00:00         110       0  25.600000  47.193333
# 19729  2016-05-27 17:10:00          90       0  25.533333  46.860000
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4  ...    T9       RH_9  \
# 19725  26.000000  41.700000  28.000000  40.760000  24.7  ...  23.2  46.700000
# ...

# %%
new_windspeed = df['Windspeed'].astype(int)

df['New Windspeed'] = new_windspeed
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.79  44.730000  19.000000  ...  45.53  6.600000        733.5    92.0
# 1  19.79  44.790000  19.000000  ...  45.56  6.483333        733.6    92.0
# 2  19.79  44.933333  18.926667  ...  45.50  6.366667        733.7    92.0
# 3  19.79  45.000000  18.890000  ...  45.40  6.250000        733.8    92.0
# 4  19.79  45.000000  18.890000  ...  45.40  6.133333        733.9    92.0
#
# ...

# %%
df['illumination'] = np.where(df['lights'] == 0, 'Not Illuminated', 'Illuminated')

df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...     T_out  Press_mm_hg  RH_out  Windspeed  \
# 0  19.79  44.730000  19.000000  ...  6.600000        733.5    92.0   7.000000
# 1  19.79  44.790000  19.000000  ...  6.483333        733.6    92.0   6.666667
# 2  19.79  44.933333  18.926667  ...  6.366667        733.7    92.0   6.333333
# 3  19.79  45.000000  18.890000  ...  6.250000        733.8    92.0   6.000000
# 4  19.79  45.000000  18.890000  ...  6.133333        733.9    92.0   5.666667
#
# ...
